# %% [markdown]
# # solve equations

# %%
#lets solve
import sympy
from sympy import symbols
from sympy.solvers import solve

# put equation here
x = symbols('x')
eq= 2*x- 10
print("x=",solve(eq,x))
# Out:
# x= [5]
